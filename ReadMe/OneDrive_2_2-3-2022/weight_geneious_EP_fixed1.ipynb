# %%
####Here we create a dictionary from voinew3.csv file just for reportables#####

dictv={}
with open ("voinew3.csv", "r") as v1:
    for lines in v1:
        if "Ref" not in lines:
            dictv[lines.split(",")[2]+lines.split(",")[3]+lines.split(",")[4].strip("\n")]="exist"
    

#########Extract individual information about variant frequency of individuals###########
#########Extract pooled information about variant frequency of pooled samples###########
with open ("GuineaAnalysis_ps.csv", "r") as r2:
    count=0
    dict1={}
    for lines in r2:
        count+=1
        if count>1:
            ####Set up a dictionary to add the weights and sample sizes to calcualte WVAF later#######
            #####This for loop is for the mutation with notification of -> in it######
            if lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ") in dict1:
                if lines.split(",")[4] in dictv:
                ###We check in the mutation is in dictv to make sure it is reportable ####
                    if lines.split(",")[-3]!="0%":
                        if "->" in lines.split(",")[-3]:
                            ####This is for mutation that is silent####
                            ####Assign dictionary with given combined pooled information#####
                            ####If there is arrow inthe column assign it as mutation###
                            ####Mutation is considered as VAF* pooled size to be added in the second part of list####
                            ####Also add pool size to the first part of list#####
                            ####wild type is consiered as adding 1*pooled size for first part of the list####
                            ####Wildtype only adds 0 to the VAF sum which is the second part of the list####
                            ####Only add VAF and poolsize to the samples when the item is already in the dictionary######
                            dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")]=[x + y for x, y in zip(dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")],[1*float(lines.split(",")[-1]),1*float(lines.split(",")[-3][-4::].strip("%"))*float(lines.split(",")[-1])])]
                        else:
                            ####This is for mutation that is not silent#####
                            ####If arrow not in given column we consider it as wildtype#####
                            ####wild type is consiered as adding 1*pooled size for first part of the list####
                            ####Wildtype only adds 0 to the VAF sum which is the second part of the list####
                            ####Only add VAF and poolsize to the samples when the item is already in the dictionary######
                            dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")]=[x + y for x, y in zip(dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")],[1*float(lines.split(",")[-1]),1*float(lines.split(",")[-3].strip("%"))*float(lines.split(",")[-1])])]
                    
            ###If the item is not in dictionary just assign the VAF and pooled size#### 
            ###Consiser mutation that VAF is not 0 and it is not in dictionary###%####        
            if lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ") not in dict1:
                if lines.split(",")[4] in dictv:
                    ###Consiser wildtype that VAF is 0 and it is in dictionary already###%####
                    if lines.split(",")[-3]!="0%":
                        dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")]=[1*float(lines.split(",")[-1]),1*float(lines.split(",")[-3].strip("%"))*float(lines.split(",")[-1])]
            if lines.split(",")[2]+","+lines.split(",")[4][0:-1]+","+lines.split(",")[3].strip("\n").strip(" ") in dict1:
                if lines.split(",")[4] in dictv:
                    ###Consiser wildtype that VAF is 0 and it is in dictionary already###%####
                    if lines.split(",")[-3]=="0%":
                        #if "C469" == lines.split(",")[4][0:-1]:
                        #    print([0,1*int(lines.split(",")[-1])])
                        dict1[lines.split(",")[2]+","+lines.split(",")[4][0:-1]+","+lines.split(",")[3].strip("\n").strip(" ")]=[x + y for x, y in zip(dict1[lines.split(",")[2]+","+lines.split(",")[4][0:-1]+","+lines.split(",")[3].strip("\n").strip(" ")],[1*float(lines.split(",")[-1]),0])]
            if lines.split(",")[2]+","+lines.split(",")[4][0:-1]+","+lines.split(",")[3].strip("\n").strip(" ") not in dict1:
                if lines.split(",")[4] in dictv:
                    ###Consiser wildtype that VAF is 0 and it is in dictionary already###%####
                    if lines.split(",")[-3]=="0%":
                        dict1[lines.split(",")[2]+","+lines.split(",")[4][0:-1]+","+lines.split(",")[3].strip("\n").strip(" ")]=[1*float(lines.split(",")[-1]),0]
                    

#########Extract individual information about variant frequency of individuals###########
#########Extract pooled information about variant frequency of pooled samples###########
######First open the previous file which contains both individual and pooled samples info with just pooled size added####
######We want to create duplicate dictionary to be used later#####
#####The way we create dictionary is same as previous for loop#####
#####This loop is for mutation without -> sign in the notification#####
with open ("GuineaAnalysis_ps.csv", "r") as r2:
    count=0
    dict3={}
    for lines in r2:
        count+=1
        if count>1:
            if lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ") in dict3:
                if lines.split(",")[4] in dictv:
                    if lines.split(",")[-3]!="0%":
                        dict3[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")]=[x + y for x, y in zip(dict3[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")],[1*int(lines.split(",")[-1]),0])]
            if lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ") not in dict3:
                if lines.split(",")[4] in dictv:
                    if lines.split(",")[-3]!="0%":
                        dict3[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")]=[1*int(lines.split(",")[-1]),0]
            if lines.split(",")[2]+","+lines.split(",")[4][0:-1]+","+lines.split(",")[3].strip("\n").strip(" ") in dict3:
                if lines.split(",")[4] in dictv:
                    if lines.split(",")[-3]=="0%":
                        dict3[lines.split(",")[2]+","+lines.split(",")[4][0:-1]+","+lines.split(",")[3].strip("\n").strip(" ")]=[x + y for x, y in zip(dict3[lines.split(",")[2]+","+lines.split(",")[4][0:-1]+","+lines.split(",")[3].strip("\n").strip(" ")],[0,1*int(lines.split(",")[-1])])]
            if lines.split(",")[2]+","+lines.split(",")[4][0:-1]+","+lines.split(",")[3].strip("\n").strip(" ") not in dict3:
                if lines.split(",")[4] in dictv:
                    if lines.split(",")[-3]=="0%":
                        dict3[lines.split(",")[2]+","+lines.split(",")[4][0:-1]+","+lines.split(",")[3].strip("\n").strip(" ")]=[0,1*int(lines.split(",")[-1])]
                                
####Once we create dictionaries we want to combine them####
####We combine the lists created for wildtype and mutations####
####We wanted to use the combination information to calculate WVAF####

with open ("weighted_geneious_EP.csv", "w") as w1:
    w1.write("Site,G_annotation,Gene,Number of Samples,SNP,WVAF,Number of Mutants, Number of wildtypes\n")
    dict2={}
    dict4={}
    for item in dict1:
        if item.split(",")[1][-1].isdigit()==False:
            dict2[item]=dict3[item]
            dict4[item]=dict1[item]
    for item2 in dict2:
        for item in dict3:
            if item.split(",")[1][-1].isdigit():
                if item.split(",")[0]==item2.split(",")[0] and item.split(",")[2]==item2.split(",")[2] and item.split(",")[1] in item2.split(",")[1]:
                    ####If there is silent mutation###
                    #####C469C is special case in which other same mutations happens####
                    #####It adds up wildtypes for same amino acid positioned mutations####
                    #####Thus, we divide up the total wildtypes to the half because of duplicate in addition######
                    if "C469" in item:
                        dict2[item2]=[x + y for x, y in zip(dict2[item2],[dict3[item][0],dict3[item][1]/2])]
                        dict4[item2]=[x + y for x, y in zip(dict4[item2],[(dict3[item][0]+dict3[item][1]/2),dict1[item][1]])]
                    else:
                        dict2[item2]=[x + y for x, y in zip(dict2[item2],dict3[item])]
                        dict4[item2]=[x + y for x, y in zip(dict4[item2],dict1[item])]
    ####This part is actually writing the mutations and lines to the new document file####
    ####After adding up all the wildtypes and mutations to a dictioanry while we write it
    ####We wan to divide the total added up VAF * pooled size / total sample size####
    for item in dict2:
        if dict2[item][0]>0:
            w1.write(item+","+str(dict2[item][1]+dict2[item][0])+","+item.split(",")[1][1::]+","+str(round((dict4[item][1]/(dict4[item][0])),2))+"%"+","+str(dict2[item][0])+","+str(dict2[item][1])+"\n")
        if dict2[item][0]==0:
            w1.write(item+","+str(dict2[item][1]+dict2[item][0])+","+item.split(",")[1][0:-1]+","+str(round((dict2[item][0]/(dict2[item][1]+dict2[item][0]))*100,2))+"%"+","+str(dict2[item][0])+","+str(dict2[item][1])+"\n")

####We loop again to process wildtpyes####
####This loop is for wildtypes meaning no variant at all#####        
with open ("GuineaAnalysis_ps.csv", "r") as r2:
    count=0
    dict1={}
    for lines in r2:
        count+=1
        if count>1:
            ###This is where we create another dictionary just for the wildtypes####
            if lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ") in dict1:
                if lines.split(",")[4] in dictv:
                    if lines.split(",")[-3]=="0%":
                        dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")]=[x + y for x, y in zip(dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")],[0,1*int(lines.split(",")[-1])])]
                if lines.split(",")[4] in dictv:
                    if lines.split(",")[-3]!="0%":
                        dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")]=[x + y for x, y in zip(dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")],[1*int(lines.split(",")[-1]),0])]
            if lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ") not in dict1:
                if lines.split(",")[4] in dictv:
                    if lines.split(",")[-3]=="0%":
                        dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")]=[0,1*int(lines.split(",")[-1])]
                if lines.split(",")[4] in dictv:    
                    if lines.split(",")[-3]!="0%":
                        dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")]=[1*int(lines.split(",")[-1]),0]
                        
#####Again we write all the wildtypes in this for loop
with open ("weighted_geneious_EP.csv", "a") as w1:
    for item in dict1:
        if dict1[item][0]==0:
            w1.write(item+","+str(dict1[item][1]+dict1[item][0])+","+item.split(",")[1][0:-1]+","+str(round((dict1[item][0]/(dict1[item][1]+dict1[item][0]))*100,2))+"%"+","+str(dict1[item][0])+","+str(dict1[item][1])+"\n")
# Out:
# {'Dorota,S108N,DHFR': [215.0, 20613.399999999998], 'Hamdalaye,S108N,DHFR': [179.0, 17389.899999999998], 'Maferinyah,S108N,DHFR': [218.0, 21641.2], 'Lay-Sarè,S108N,DHFR': [166.0, 16011.5], 'Dorota,C59R,DHFR': [215.0, 20720.600000000002], 'Dorota,K76T,PfCRT': [32.0, 1520.1], 'Dorota,I356T,PfCRT': [12.0, 622.3], 'Hamdalaye,C59R,DHFR': [177.0, 17262.4], 'Hamdalaye,K76T,PfCRT': [51.0, 2414.2], 'Hamdalaye,I356T,PfCRT': [37.0, 973.0], 'Maferinyah,C59R,DHFR': [217.0, 21467.9], 'Lay-Sarè,C59R,DHFR': [165.0, 15927.0], 'Lay-Sarè,I356T,PfCRT': [15.0, 1250.0], 'Lay-Sarè,K76T,PfCRT': [36.0, 1967.0], 'Maferinyah,C350R,PfCRT': [5.0, 125.0], 'Maferinyah,K76T,PfCRT': [16.0, 663.5], 'Dorota,M343L,PfCRT': [5.0, 62.5], 'Dorota,S436A,DHPS': [202.0, 8151.899999999999], 'Dorota,A437G,DHPS': [211.0, 18700.8], 'Dorota,K540E,DHPS': [69.0, 1416.7], 'Hamdalaye,A437G,DHPS': [190.0, 14202.9], 'Hamdalaye,S436A,DHPS': [202.0, 10922.400000000003], 'Hamdalaye,Q271E,PfCRT': [41.0, 1690.5], 'Maferinyah,A437G,DHPS': [212.0, 17164.6], 'Lay-Sarè,S436A,DHPS': [132.0, 6775.1], 'Lay-Sarè,A437G,DHPS': [158.0, 12616.4], 'Lay-Sarè,Q271E,PfCRT': [10.0, 416.5], 'Lay-Sarè,K540E,DHPS': [16.0, 483.3], 'Lay-Sarè,A581G,DHPS': [2.0, 169.2], 'Maferinyah,S436A,DHPS': [161.0, 8155.700000000001], 'Maferinyah,A581G,DHPS': [7.0, 506.5], 'Maferinyah,Q271E,PfCRT': [6.0, 600.0], 'Maferinyah,K540E,DHPS': [46.0, 1034.2], 'Dorota,A581G,DHPS': [25.0, 654.0], 'Dorota,Q271E,PfCRT': [31.0, 1297.0], 'Hamdalaye,K540E,DHPS': [45.0, 1348.0], 'Hamdalaye,A581G,DHPS': [6.0, 187.5], 'Dorota,N75E,PfCRT': [32.0, 1509.2], 'Hamdalaye,N75E,PfCRT': [51.0, 2130.5], 'Lay-Sarè,N75E,PfCRT': [36.0, 1667.5], 'Maferinyah,N75E,PfCRT': [16.0, 638.5], 'Dorota,N51I,DHFR': [215.0, 19910.8], 'Dorota,Y184F,PfMDR1': [157.0, 10913.6], 'Dorota,M74I,PfCRT': [32.0, 1509.2], 'Dorota,A613S,DHPS': [104.0, 3436.4], 'Dorota,A220S,PfCRT': [16.0, 850.0], 'Hamdalaye,N51I,DHFR': [173.0, 16127.400000000001], 'Hamdalaye,Y184F,PfMDR1': [108.0, 8373.8], 'Hamdalaye,A613S,DHPS': [47.0, 1280.8], 'Hamdalaye,M74I,PfCRT': [49.0, 2182.2], 'Maferinyah,N51I,DHFR': [218.0, 21509.4], 'Lay-Sarè,Y184F,PfMDR1': [86.0, 8016.5], 'Lay-Sarè,N51I,DHFR': [166.0, 15650.300000000001], 'Lay-Sarè,A613S,DHPS': [65.0, 2421.6], 'Lay-Sarè,M74I,PfCRT': [36.0, 1520.0], 'Lay-Sarè,A220S,PfCRT': [32.0, 2825.0], 'Lay-Sarè,N86Y,PfMDR1': [10.0, 1000.0], 'Lay-Sarè,D1246Y,PfMDR1': [5.0, 300.0], 'Lay-Sarè,A578S,K13': [1.0, 7.8], 'Maferinyah,Y184F,PfMDR1': [144.0, 11544.5], 'Maferinyah,A613S,DHPS': [64.0, 2308.3], 'Maferinyah,A578S,K13': [10.0, 152.0], 'Maferinyah,M74I,PfCRT': [20.0, 599.0], 'Maferinyah,A220S,PfCRT': [10.0, 562.5], 'Maferinyah,D1246Y,PfMDR1': [10.0, 76.5], 'Dorota,N86Y,PfMDR1': [55.0, 1754.0], 'Dorota,D1246Y,PfMDR1': [41.0, 1422.0], 'Dorota,R371I,PfCRT': [5.0, 500.0], 'Hamdalaye,A220S,PfCRT': [40.0, 965.0], 'Hamdalaye,A578S,K13': [5.0, 77.0], 'Hamdalaye,N86Y,PfMDR1': [21.0, 892.0], 'Hamdalaye,R371I,PfCRT': [4.0, 200.0], 'Lay-Sarè,I543,K13': [173.0, 0], 'Maferinyah,N1042,PfMDR1': [165.0, 0], 'Hamdalaye,N1042,PfMDR1': [135.0, 0], 'Hamdalaye,D1246,PfMDR1': [132.0, 0], 'Dorota,S436,DHPS': [9.0, 0], 'Dorota,A581,DHPS': [186.0, 0], 'Dorota,G449,K13': [210.0, 0], 'Hamdalaye,A675,K13': [217.0, 0], 'Hamdalaye,N75,PfCRT': [104.0, 0], 'Hamdalaye,R561,K13': [219.0, 0], 'Hamdalaye,V568,K13': [219.0, 0], 'Hamdalaye,C72,PfCRT': [154.0, 0], 'Hamdalaye,V73,PfCRT': [154.0, 0], 'Hamdalaye,M74,PfCRT': [103.0, 0], 'Hamdalaye,K76,PfCRT': [104.0, 0], 'Hamdalaye,Q271,PfCRT': [83.0, 0], 'Hamdalaye,A581,DHPS': [200.0, 0], 'Hamdalaye,I164,DHFR': [168.0, 0], 'Hamdalaye,P441,K13': [221.0, 0], 'Hamdalaye,Y493,K13': [217.0, 0], 'Hamdalaye,I218,PfCRT': [140.0, 0], 'Hamdalaye,K540,DHPS': [148.0, 0], 'Maferinyah,R622,K13': [235.0, 0], 'Lay-Sarè,D1246,PfMDR1': [59.0, 0], 'Lay-Sarè,S1034,PfMDR1': [86.0, 0], 'Lay-Sarè,N1042,PfMDR1': [86.0, 0], 'Lay-Sarè,R371,PfCRT': [15.0, 0], 'Lay-Sarè,N86,PfMDR1': [50.0, 0], 'Lay-Sarè,C350,PfCRT': [99.0, 0], 'Lay-Sarè,G353,PfCRT': [99.0, 0], 'Lay-Sarè,Q271,PfCRT': ...
# {'Dorota,S108N,DHFR': [216.0, 20613.399999999998], 'Hamdalaye,S108N,DHFR': [179.0, 17389.899999999998], 'Maferinyah,S108N,DHFR': [218.0, 21641.2], 'Lay-Sarè,S108N,DHFR': [166.0, 16011.5], 'Dorota,C59R,DHFR': [216.0, 20720.600000000002], 'Dorota,K76T,PfCRT': [176.0, 1520.1], 'Dorota,I356T,PfCRT': [156.0, 622.3], 'Hamdalaye,C59R,DHFR': [177.0, 17262.4], 'Hamdalaye,K76T,PfCRT': [155.0, 2414.2], 'Hamdalaye,I356T,PfCRT': [133.0, 973.0], 'Maferinyah,C59R,DHFR': [217.0, 21467.9], 'Lay-Sarè,C59R,DHFR': [166.0, 15927.0], 'Lay-Sarè,I356T,PfCRT': [94.0, 1250.0], 'Lay-Sarè,K76T,PfCRT': [112.0, 1967.0], 'Maferinyah,C350R,PfCRT': [110.0, 125.0], 'Maferinyah,K76T,PfCRT': [150.0, 663.5], 'Dorota,M343L,PfCRT': [151.0, 62.5], 'Dorota,S436A,DHPS': [211.0, 8151.899999999999], 'Dorota,A437G,DHPS': [211.0, 18700.8], 'Dorota,K540E,DHPS': [209.0, 1416.7], 'Hamdalaye,A437G,DHPS': [212.0, 14202.9], 'Hamdalaye,S436A,DHPS': [212.0, 10922.400000000003], 'Hamdalaye,Q271E,PfCRT': [124.0, 1690.5], 'Maferinyah,A437G,DHPS': [214.0, 17164.6], 'Lay-Sarè,S436A,DHPS': [163.0, 6775.1], 'Lay-Sarè,A437G,DHPS': [168.0, 12616.4], 'Lay-Sarè,Q271E,PfCRT': [66.0, 416.5], 'Lay-Sarè,K540E,DHPS': [148.0, 483.3], 'Lay-Sarè,A581G,DHPS': [164.0, 169.2], 'Maferinyah,S436A,DHPS': [209.0, 8155.700000000001], 'Maferinyah,A581G,DHPS': [209.0, 506.5], 'Maferinyah,Q271E,PfCRT': [119.0, 600.0], 'Maferinyah,K540E,DHPS': [199.0, 1034.2], 'Dorota,A581G,DHPS': [211.0, 654.0], 'Dorota,Q271E,PfCRT': [137.0, 1297.0], 'Hamdalaye,K540E,DHPS': [193.0, 1348.0], 'Hamdalaye,A581G,DHPS': [206.0, 187.5], 'Dorota,N75E,PfCRT': [176.0, 1509.2], 'Hamdalaye,N75E,PfCRT': [155.0, 2130.5], 'Lay-Sarè,N75E,PfCRT': [107.0, 1667.5], 'Maferinyah,N75E,PfCRT': [150.0, 638.5], 'Dorota,N51I,DHFR': [216.0, 19910.8], 'Dorota,Y184F,PfMDR1': [180.0, 10913.6], 'Dorota,M74I,PfCRT': [176.0, 1509.2], 'Dorota,A613S,DHPS': [215.0, 3436.4], 'Dorota,A220S,PfCRT': [152.0, 850.0], 'Hamdalaye,N51I,DHFR': [173.0, 16127.400000000001], 'Hamdalaye,Y184F,PfMDR1': [135.0, 8373.8], 'Hamdalaye,A613S,DHPS': [207.0, 1280.8], 'Hamdalaye,M74I,PfCRT': [152.0, 2182.2], 'Maferinyah,N51I,DHFR': [218.0, 21509.4], 'Lay-Sarè,Y184F,PfMDR1': [99.0, 8016.5], 'Lay-Sarè,N51I,DHFR': [166.0, 15650.300000000001], 'Lay-Sarè,A613S,DHPS': [165.0, 2421.6], 'Lay-Sarè,M74I,PfCRT': [107.0, 1520.0], 'Lay-Sarè,A220S,PfCRT': [101.0, 2825.0], 'Lay-Sarè,N86Y,PfMDR1': [60.0, 1000.0], 'Lay-Sarè,D1246Y,PfMDR1': [64.0, 300.0], 'Lay-Sarè,A578S,K13': [173.0, 7.8], 'Maferinyah,Y184F,PfMDR1': [171.0, 11544.5], 'Maferinyah,A613S,DHPS': [214.0, 2308.3], 'Maferinyah,A578S,K13': [235.0, 152.0], 'Maferinyah,M74I,PfCRT': [149.0, 599.0], 'Maferinyah,A220S,PfCRT': [106.0, 562.5], 'Maferinyah,D1246Y,PfMDR1': [162.0, 76.5], 'Dorota,N86Y,PfMDR1': [144.0, 1754.0], 'Dorota,D1246Y,PfMDR1': [169.0, 1422.0], 'Dorota,R371I,PfCRT': [69.0, 500.0], 'Hamdalaye,A220S,PfCRT': [133.0, 965.0], 'Hamdalaye,A578S,K13': [219.0, 77.0], 'Hamdalaye,N86Y,PfMDR1': [108.0, 892.0], 'Hamdalaye,R371I,PfCRT': [54.0, 200.0]}
# 216.0 20613.399999999998
# 179.0 17389.899999999998
# 218.0 21641.2
# 166.0 16011.5
# 216.0 20720.600000000002
# 176.0 1520.1
# 156.0 622.3
# 177.0 17262.4
# 155.0 2414.2
# 133.0 973.0
# 217.0 21467.9
# 166.0 15927.0
# 94.0 1250.0
# 112.0 1967.0
# 110.0 125.0
# 150.0 663.5
# 151.0 62.5
# 211.0 8151.899999999999
# 211.0 18700.8
# 209.0 1416.7
# 212.0 14202.9
# 212.0 10922.400000000003
# 124.0 1690.5
# 214.0 17164.6
# 163.0 6775.1
# 168.0 12616.4
# 66.0 416.5
# 148.0 483.3
# 164.0 169.2
# 209.0 8155.700000000001
# 209.0 506.5
# 119.0 600.0
# 199.0 1034.2
# 211.0 654.0
# 137.0 1297.0
# 193.0 1348.0
# 206.0 187.5
# 176.0 1509.2
# 155.0 2130.5
# 107.0 1667.5
# 150.0 638.5
# 216.0 19910.8
# 180.0 10913.6
# 176.0 1509.2
# 215.0 3436.4
# 152.0 850.0
# 173.0 16127.400000000001
# 135.0 8373.8
# 207.0 1280.8
# 152.0 2182.2
# 218.0 21509.4
# 99.0 8016.5
# 166.0 15650.300000000001
# 165.0 2421.6
# 107.0 1520.0
# 101.0 2825.0
# 60.0 1000.0
# 64.0 300.0
# 173.0 7.8
# 171.0 11544.5
# 214.0 2308.3
# 235.0 152.0
# 149.0 599.0
# 106.0 562.5
# 162.0 76.5
# 144.0 1754.0
# 169.0 1422.0
# 69.0 500.0
# 133.0 965.0
# 219.0 77.0
# 108.0 892.0
# 54.0 200.0
