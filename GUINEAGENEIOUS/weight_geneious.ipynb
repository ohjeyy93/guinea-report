# %%
#########Extract individual information about variant frequency of individuals###########
#########Extract pooled information about variant frequency of pooled samples###########
with open ("GuineaAnalysis_ps.csv", "r") as r2:
    count=0
    dict1={}
    for lines in r2:
        count+=1
        if count>1:
            #if "Do" in lines and "A220S" in lines:
            #    print(lines)
            #print(lines)
            #print(lines.split(",")[8])
            #print(lines.split(",")[7])
            #print(lines.split(",")[1])
            ########### Combine individual variant frequency with the pooled variant frequencies##########
            #print(lines.split(",")[2])
            #print(lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3])
            #print(lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" "))
            #print(lines.split(",")[-3])
            #print(lines.split(",")[4][0:-1])
            if lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ") in dict1:
                #print([lines.split(",")[1],float(lines.split(",")[7].strip("%"))*float(lines.split(",")[1])])
                #print(dict1[lines.split(",")[4]+","+lines.split(",")[6]])
                #print(dict1[lines.split(",")[4].strip(" ")+","+lines.split(",")[6]])
                #print(dict1[lines.split(",")[4].strip(" ")+","+lines.split(",")[6]])
                #if "C59R" == lines.split(",")[6]:
                #    print(lines.split(",")[7])
                #    print([float(lines.split(",")[1]),float(lines.split(",")[7].strip("%"))*float(lines.split(",")[1])])
                #print(lines.split(",")[8])
                #print(lines.split(",")[6].split(" ")[0])
                #if "DHPS" in lines:
                #    print(lines)
                #print(lines.split(",")[3].strip("\n").strip(" "))
                #if lines.split(",")[-3]=="0%":
                    #if "DHPS" in lines:
                    #    print(lines)
                #    dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")]=[x + y for x, y in zip(dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")],[0,1*int(lines.split(",")[-1])])]
                if lines.split(",")[-3]!="0%":
                    dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")]=[x + y for x, y in zip(dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")],[1*int(lines.split(",")[-1]),0])]
            if lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ") not in dict1:
                #print([float(lines.split(",")[1]),float(lines.split(",")[7].strip("%"))*float(lines.split(",")[1])])
                #print([float(lines.split(",")[1]),float(lines.split(",")[7].strip("%"))*float(lines.split(",")[1])])
                #print(lines.split(",")[4].strip(" ")+","+lines.split(",")[6]+","+lines.split(",")[8])
                #print(lines)
                #if "DHPS" in lines:
                #    print(lines)
                #if lines.split(",")[-3]=="0%":
                #    dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")]=[0,1*int(lines.split(",")[-1])]
                if lines.split(",")[-3]!="0%":
                    dict1[lines.split(",")[2]+","+lines.split(",")[4]+","+lines.split(",")[3].strip("\n").strip(" ")]=[1*int(lines.split(",")[-1]),0]
                #print
#print(dict1)
            if lines.split(",")[2]+","+lines.split(",")[4][0:-1]+","+lines.split(",")[3].strip("\n").strip(" ") in dict1:
                if lines.split(",")[-3]=="0%":
                    dict1[lines.split(",")[2]+","+lines.split(",")[4][0:-1]+","+lines.split(",")[3].strip("\n").strip(" ")]=[x + y for x, y in zip(dict1[lines.split(",")[2]+","+lines.split(",")[4][0:-1]+","+lines.split(",")[3].strip("\n").strip(" ")],[0,1*int(lines.split(",")[-1])])]
            if lines.split(",")[2]+","+lines.split(",")[4][0:-1]+","+lines.split(",")[3].strip("\n").strip(" ") not in dict1:
                if lines.split(",")[-3]=="0%":
                    dict1[lines.split(",")[2]+","+lines.split(",")[4][0:-1]+","+lines.split(",")[3].strip("\n").strip(" ")]=[0,1*int(lines.split(",")[-1])]
            
            
########Create a csv file with information about weighted average############
with open ("weighted_geneious.csv", "w") as w1:
    w1.write("Site,SNP,Gene,Number of Samples,SNP,Weight of Variants,Number of Mutants, Number of wildtypes\n")
    dict2={}
    for item in dict1:
        if item.split(",")[1][-1].isdigit()==False:
            dict2[item]=dict1[item]
    for item2 in dict2:
        for item in dict1:
            if item.split(",")[1][-1].isdigit():
                if item.split(",")[0]==item2.split(",")[0] and item.split(",")[2]==item2.split(",")[2] and item.split(",")[1] in item2.split(",")[1]:
                    #print(dict1[item])
                    #print(dict2[item2])
                    dict2[item2]=[x + y for x, y in zip(dict2[item2],dict1[item])]
                    #print(dict2[item2])
    for item in dict2:
        #print(dict2[item][0]>0)
        if dict2[item][0]>0:
            #print(dict2[item][1]+dict2[item][0])
            w1.write(item+","+str(dict2[item][1]+dict2[item][0])+","+item.split(",")[1]+","+str(round((dict2[item][0]/(dict2[item][1]+dict2[item][0]))*100,2))+"%"+","+str(dict2[item][0])+","+str(dict2[item][1])+"\n")
        if dict2[item][0]==0:
            #print(dict2[item][1]+dict2[item][0])
            w1.write(item+","+str(dict2[item][1]+dict2[item][0])+","+item.split(",")[1][0:-1]+","+str(round((dict2[item][0]/(dict2[item][1]+dict2[item][0]))*100,2))+"%"+","+str(dict2[item][0])+","+str(dict2[item][1])+"\n")
        
        #print(dict1[item][0],dict1[item][1])
        #print(dict1[item])
        #print(dict1[item][0])
        #print(dict1[item][1])
        #w1.write(item+","+str(dict1[item][1]+dict1[item][0])+","+str(round((dict1[item][0]/(dict1[item][1]+dict1[item][0])),3)*100)+"%"+","+str(dict1[item][0])+","+str(dict1[item][1])+"\n")
